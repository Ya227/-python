# %% [markdown]
# <a href="https://colab.research.google.com/github/Ya227/-python/blob/main/%D0%9A%D0%B0%D1%80%D0%B0%D1%81%D1%91%D0%B2%D0%B0_%D0%AF%D0%BD%D0%B0_5%D0%B4%D0%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Инициализация нового локального репозитория - git init
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) Добавление файлов в индекс для коммита - git add
#
# 3) Создание нового коммита - git commit -m "Commit message"
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) Просмотр истории коммитов - git log
#
# 5) Просмотр изменений в файлах перед коммитом - git diff
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) Откат изменений в файле до предыдущего коммита - git checkout --
#
# 7) Создание новой ветки - git branch
#
# 8) Переключение между ветками - git checkout
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9) Слияние веток - git merge
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10) Удаление ветки - git branch -d
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Чтобы изменить содержимое ячейки, дважды нажмите на нее (или выберите "Ввод")
#
# 11) Изменение сообщения последнего коммита - git commit --amend
#
# 12) Удаление файла из репозитория и истории коммитов - git rm
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13) Игнорирование файлов и папок с помощью .gitignore - создание и редактирование файла .gitignore
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14) Просмотр различий между ветками - git diff
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 15) Отмена изменений в файле после добавления в индекс - git reset HEAD
#
# 16) Просмотр информации о состоянии репозитория - git status
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 17) Переименование файлов - git mv
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18) Отображение информации о коммите - git show
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 19) Возврат к определенному коммиту - git checkout
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 20) Создание и применение патчей - git format-patch и git apply
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 21) Изменение порядка коммитов - git rebase -i
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 22) Изменение авторства коммитов - git commit --amend --author="Author Name "
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 23) Изменение истории коммитов с помощью rebase - git rebase
#
# 24) Использование stash для временного сохранения изменений - git stash и git stash apply
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 25) Применение изменений из одной ветки в другую с помощью cherry-pick - git cherry-pick
#
# 26) Просмотр информации о ветках и удаленных репозиториях - git branch, git remote -v
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 27) Изменение URL удаленного репозитория - git remote set-url origin
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 28) Удаление коммитов из истории - git reset или git rebase -i
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 29) Использование алиасов для команд Git - git config --global alias. ""
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30) Использование подмодулей для работы с вложенными репозиториями - git submodule
# ![image.png](data:image/png;base64,...)
